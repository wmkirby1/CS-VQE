# %%
import json
import numpy
import scipy
import utils.molecule_tools as mol
import utils.qonversion_tools as qonvert
import utils.linalg_tools as la
import utils.bit_tools as bit
import fermions.yaferp.misc.tapering as taper
import fermions.yaferp.general.fermions as fermions
import fermions.yaferp.general.sparseFermions as sparseFermions

# %%
with open('data/molecule_data.json', 'r') as json_file:
    molecule_data = json.load(json_file)
print(len(molecule_data))
list(molecule_data.keys())
# Out:
# 32
# ['H2_3-21G_SINGLET',
#  'H6_STO-3G_SINGLET',
#  'H2_6-31G_SINGLET',
#  'H2_6-311G_SINGLET',
#  'H3+_STO-3G_SINGLET',
#  'H3+_3-21G_SINGLET',
#  'H3+_STO-3G_SINGLET_alt',
#  'HeH+_3-21G_SINGLET',
#  'HeH+_3-21G_SINGLET_alt',
#  'HeH+_6-311G_SINGLET',
#  'H2O_STO-3G_SINGLET',
#  'H2O_STO-3G_SINGLET_alt',
#  'BeH+_STO-3G_SINGLET',
#  'LiH_STO-3G_SINGLET',
#  'CH+_STO-3G_SINGLET',
#  'HF_STO-3G_SINGLET',
#  'B+_STO-3G_SINGLET',
#  'N+_STO-3G_SINGLET',
#  'OH+_STO-3G_SINGLET',
#  'O_STO-3G_SINGLET',
#  'CH2_STO-3G_SINGLET',
#  'BeH2_STO-3G_SINGLET',
#  'Be_STO-3G_SINGLET',
#  'C_STO-3G_SINGLET',
#  'NH_STO-3G_SINGLET',
#  'Ne_STO-3G_SINGLET',
#  'F+_STO-3G_SINGLET',
#  'Li+_STO-3G_SINGLET',
#  'BH_STO-3G_SINGLET',
#  'NeH+_STO-3G_SINGLET',
#  'NH2+_STO-3G_SINGLET',
#  'BH2+_STO-3G_SINGLET']

# %%
molecules = ['LiH_STO-3G_SINGLET','HF_STO-3G_SINGLET', 'C_STO-3G_SINGLET', 'Be_STO-3G_SINGLET']

# %%
def hfDegenerateGroundState(oplist):
    oplistDiag = [x for x in oplist if 2 not in x[1] and 1 not in x[1]]
    mat = sparseFermions.commutingOplistToMatrix(oplistDiag)
    matDiag = mat.diagonal()
    hfEnergy = matDiag.min()
    indices = numpy.nonzero(abs(matDiag - hfEnergy) < 1e-8)[0]
    normalization = 1./(len(indices)**(1/2))
    fullSpace = mat.shape[0]
    matDat = [normalization]*len(indices)
    hfState = scipy.sparse.csc_matrix((matDat,(indices,[0]*len(indices))),shape=(fullSpace,1),dtype=numpy.complex128)
    return hfState, indices

# %%
for speciesname in molecule_data:
    print(speciesname)
    atoms, coords, mult, charge, basis, sector = molecule_data[speciesname].values()
    
    construct_mol=mol.construct_molecule(atoms=atoms, 
                                   coords=coords, 
                                   charge=charge, 
                                   multiplicity=mult, 
                                   basis=basis, 
                                   taper=False)
    
    ham_untapered = construct_mol['hamiltonian']
    untap_hf_config = construct_mol['hf_config']
    try:
        construct_mol=mol.construct_molecule(atoms=atoms, 
                                       coords=coords, 
                                       charge=charge, 
                                       multiplicity=mult, 
                                       basis=basis, 
                                       taper=True, 
                                       sym_sector=sector)
        ham_tapered_qiskit = construct_mol['hamiltonian']

        ham_untapered_indexed = qonvert.dict_to_list_index(ham_untapered)
        #taper.hfDegenerateGroundState(ham_untapered_indexed)
        hf_index_andrew = hfDegenerateGroundState(ham_untapered_indexed)[1]
        hf_index_qiskit = bit.bin_to_int(untap_hf_config)
        print('HF index:', hf_index_andrew, hf_index_qiskit)
        
        ham_tapered_andrew_1 = qonvert.index_list_to_dict(taper.taperOplist(oplist=ham_untapered_indexed, hfStateIndex=hf_index_andrew[0]))
        ham_tapered_andrew_2 = qonvert.index_list_to_dict(taper.taperOplist(oplist=ham_untapered_indexed, hfStateIndex=hf_index_qiskit))

        ham_untap_mat = qonvert.dict_to_WeightedPauliOperator(ham_untapered).to_matrix()
        ham_tap_1_mat = qonvert.dict_to_WeightedPauliOperator(ham_tapered_qiskit).to_matrix()
        ham_tap_2_1_mat = qonvert.dict_to_WeightedPauliOperator(ham_tapered_andrew_1).to_matrix()
        ham_tap_2_2_mat = qonvert.dict_to_WeightedPauliOperator(ham_tapered_andrew_2).to_matrix()


        print('Ground state energy untapered:          ',la.get_ground_state(ham_untap_mat)[0])
        print('Ground state energy tapered with Qiskit:',la.get_ground_state(ham_tap_1_mat)[0])
        print('Ground state energy tapered with Andrew (andrew hf):',la.get_ground_state(ham_tap_2_1_mat)[0])
        print('Ground state energy tapered with Andrew (qiskit hf):',la.get_ground_state(ham_tap_2_2_mat)[0])

        print('Qiskit num qubits: ',len(list(ham_tapered_qiskit.keys())[0]))
        print('Andrew num qubits: ',len(list(ham_tapered_andrew_1.keys())[0]), '\n')
    except:
        print('<!> Tapering went wrong \n')
# Out:
# H2_3-21G_SINGLET
# Attempting to taper 8 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, 1), tapering successful!
#
# HF index: [192] 136
# Ground state energy untapered:           -1.1478774014540079
# Ground state energy tapered with Qiskit: -1.147877401454005
# Ground state energy tapered with Andrew (andrew hf): -0.23679831458316108
# Ground state energy tapered with Andrew (qiskit hf): -0.23679831458316297
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# H6_STO-3G_SINGLET
# Attempting to taper 12 --> 9 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, 1), tapering successful!
#
# HF index: [4032] 3640
# Ground state energy untapered:           -3.2360662798923574
# Ground state energy tapered with Qiskit: -3.236066279892362
# Ground state energy tapered with Andrew (andrew hf): -2.8848852002028815
# Ground state energy tapered with Andrew (qiskit hf): -2.884885200202895
# Qiskit num qubits:  9
# Andrew num qubits:  9
#
# H2_6-31G_SINGLET
# Attempting to taper 8 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, 1), tapering successful!
#
# HF index: [192] 136
# Ground state energy untapered:           -1.1516894969527642
# Ground state energy tapered with Qiskit: -1.1516894969527687
# Ground state energy tapered with Andrew (andrew hf): -0.31658223870978913
# Ground state energy tapered with Andrew (qiskit hf): -0.31658223870978974
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# H2_6-311G_SINGLET
# Attempting to taper 12 --> 9 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, 1), tapering successful!
#
# HF index: [3072] 2080
# Ground state energy untapered:           -1.1534920427901472
# Ground state energy tapered with Qiskit: -1.1534920427901258
# Ground state energy tapered with Andrew (andrew hf): -0.6063561273590811
# Ground state energy tapered with Andrew (qiskit hf): -0.6063561273590763
# Qiskit num qubits:  9
# Andrew num qubits:  9
#
# H3+_STO-3G_SINGLET
# Attempting to taper 6 --> 3 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1), tapering successful!
#
# HF index: [52 56] 36
# Ground state energy untapered:           -1.3609986808737162
# Ground state energy tapered with Qiskit: -1.3609981354885563
# Ground state energy tapered with Andrew (andrew hf): -1.2744126997268543
# Ground state energy tapered with Andrew (qiskit hf): -1.274412699726854
# Qiskit num qubits:  3
# Andrew num qubits:  3
#
# H3+_3-21G_SINGLET
# Attempting to taper 12 --> 9 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1), tapering successful!
#
# HF index: [3328 3584] 2080
# Ground state energy untapered:           -1.4833600935031797
# Ground state energy tapered with Qiskit: -1.4833599614328634
# Ground state energy tapered with Andrew (andrew hf): -1.2732954754307821
# Ground state energy tapered with Andrew (qiskit hf): -1.2732954754307777
# Qiskit num qubits:  9
# Andrew num qubits:  9
#
# H3+_STO-3G_SINGLET_alt
# Attempting to taper 6 --> 3 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1, 1), tapering successful!
#
# HF index: [52 56] 36
# Ground state energy untapered:           -1.4864370775519384
# Ground state energy tapered with Qiskit: -1.4864370775519364
# Ground state energy tapered with Andrew (andrew hf): -1.2610034758606714
# Ground state energy tapered with Andrew (qiskit hf): -1.2610034758606734
# Qiskit num qubits:  3
# Andrew num qubits:  3
#
# HeH+_3-21G_SINGLET
# Attempting to taper 8 --> 6 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1), tapering successful!
#
# HF index: [208 224] 136
# Ground state energy untapered:           -3.1728169735771075
# Ground state energy tapered with Qiskit: -3.172816973577092
# Ground state energy tapered with Andrew (andrew hf): -2.924585272745444
# Ground state energy tapered with Andrew (qiskit hf): -2.9245852727454484
# Qiskit num qubits:  6
# Andrew num qubits:  6
#
# HeH+_3-21G_SINGLET_alt
# Attempting to taper 8 --> 6 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1), tapering successful!
#
# HF index: [208 224] 136
# Ground state energy untapered:           -3.1736340008768913
# Ground state energy tapered with Qiskit: -3.173634000876892
# Ground state energy tapered with Andrew (andrew hf): -2.9259297025707416
# Ground state energy tapered with Andrew (qiskit hf): -2.9259297025707456
# Qiskit num qubits:  6
# Andrew num qubits:  6
#
# HeH+_6-311G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Tapering went wrong
# H2O_STO-3G_SINGLET
# Attempting to taper 14 --> 10 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, -1, 1), tapering successful!
#
# HF index: [16368] 15996
# Ground state energy untapered:           -75.01084664817131
# Ground state energy tapered with Qiskit: -75.01084664817041
# Ground state energy tapered with Andrew (andrew hf): -75.01084664817043
# Ground state energy tapered with Andrew (qiskit hf): -75.01084664817073
# Qiskit num qubits:  10
# Andrew num qubits:  10
#
# H2O_STO-3G_SINGLET_alt
# Attempting to taper 14 --> 10 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, -1, 1), tapering successful!
#
# HF index: [16368] 15996
# Ground state energy untapered:           -75.02163993276636
# Ground state energy tapered with Qiskit: -75.02163993276531
# Ground state energy tapered with Andrew (andrew hf): -75.02163993276568
# Ground state energy tapered with Andrew (qiskit hf): -75.0216399327659
# Qiskit num qubits:  10
# Andrew num qubits:  10
#
# BeH+_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energy mismatch with target problem in sector (1, 1, 1, 1), trying another...
# Energies match in sector (1, 1, 1, -1), tapering successful!
#
# HF index: [3904 3968] 3120
# Ground state energy untapered:           -14.956955614466747
# Ground state energy tapered with Qiskit: -14.956955614466425
# Ground state energy tapered with Andrew (andrew hf): -14.685828174532801
# Ground state energy tapered with Andrew (qiskit hf): -14.68582817453282
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# LiH_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, 1, 1), tapering successful!
#
# HF index: [3840] 3120
# Ground state energy untapered:           -7.8827622309720145
# Ground state energy tapered with Qiskit: -7.8827622309719665
# Ground state energy tapered with Andrew (andrew hf): -7.882762230971973
# Ground state energy tapered with Andrew (qiskit hf): -7.882762230972003
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# CH+_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energy mismatch with target problem in sector (1, 1, 1, 1), trying another...
# Energy mismatch with target problem in sector (1, 1, 1, -1), trying another...
# Energy mismatch with target problem in sector (1, 1, -1, 1), trying another...
# Energies match in sector (-1, 1, 1, 1), tapering successful!
#
# HF index: [4036 4040 4048 4064] 3640
# Ground state energy untapered:           -37.81236457784725
# Ground state energy tapered with Qiskit: -37.81236457784677
# Ground state energy tapered with Andrew (andrew hf): -37.516985238751765
# Ground state energy tapered with Andrew (qiskit hf): -37.516985238751815
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# HF_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, -1), tapering successful!
#
# HF index: [4092] 4030
# Ground state energy untapered:           -98.60330177725996
# Ground state energy tapered with Qiskit: -98.60330177725945
# Ground state energy tapered with Andrew (andrew hf): -98.13175135661554
# Ground state energy tapered with Andrew (qiskit hf): -98.13175135661501
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# B+_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, 1, 1, 1), tapering successful!
#
# HF index: [961 962 964 968 976 992] 792
# Ground state energy untapered:           -24.189264917100367
# Ground state energy tapered with Qiskit: -24.189264917100274
# Ground state energy tapered with Andrew (andrew hf): -23.8141804956429
# Ground state energy tapered with Andrew (qiskit hf): -23.814180495642894
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# N+_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, -1, -1, -1), tapering successful!
#
# HF index: [ 981 1002] 924
# Ground state energy untapered:           -53.71901016259449
# Ground state energy tapered with Qiskit: -53.719010162593925
# Ground state energy tapered with Andrew (andrew hf): -53.18116795713685
# Ground state energy tapered with Andrew (qiskit hf): -53.1811679571369
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# OH+_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energy mismatch with target problem in sector (1, 1, 1, 1), trying another...
# Energy mismatch with target problem in sector (1, 1, 1, -1), trying another...
# Energy mismatch with target problem in sector (1, 1, -1, 1), trying another...
# Energies match in sector (-1, 1, 1, 1), tapering successful!
#
# HF index: [4060 4076 4084 4088] 3900
# Ground state energy untapered:           -74.39362962132623
# Ground state energy tapered with Qiskit: -74.39362962132513
# Ground state energy tapered with Andrew (andrew hf): -73.9668856285822
# Ground state energy tapered with Andrew (qiskit hf): -73.9668856285825
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# O_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, -1, 1, 1), tapering successful!
#
# HF index: [ 983  989 1003 1006 1013 1018] 990
# Ground state energy untapered:           -73.80415023325598
# Ground state energy tapered with Qiskit: -73.80415023325571
# Ground state energy tapered with Andrew (andrew hf): -72.31180548524067
# Ground state energy tapered with Andrew (qiskit hf): -72.31180548524054
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# CH2_STO-3G_SINGLET
# Attempting to taper 14 --> 10 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1, -1, 1), tapering successful!
#
# HF index: [16208 16288] 15480
# Ground state energy untapered:           -38.47392829419466
# Ground state energy tapered with Qiskit: -38.47392829419357
# Ground state energy tapered with Andrew (andrew hf): -37.988190884098714
# Ground state energy tapered with Andrew (qiskit hf): -37.98819088409843
# Qiskit num qubits:  10
# Andrew num qubits:  10
#
# BeH2_STO-3G_SINGLET
# Attempting to taper 14 --> 9 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, -1, 1), tapering successful!
#
# HF index: [16128] 14448
# Ground state energy untapered:           -15.59474614566057
# Ground state energy tapered with Qiskit: -15.594746145660576
# Ground state energy tapered with Andrew (andrew hf): -15.594746145660407
# Ground state energy tapered with Andrew (qiskit hf): -15.594746145660427
# Qiskit num qubits:  9
# Andrew num qubits:  9
#
# Be_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, 1, 1, 1), tapering successful!
#
# HF index: [960] 792
# Ground state energy untapered:           -14.403655108067678
# Ground state energy tapered with Qiskit: -14.403655108067749
# Ground state energy tapered with Andrew (andrew hf): -13.500942847274942
# Ground state energy tapered with Andrew (qiskit hf): -13.500942847274908
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# C_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, 1, 1, -1), tapering successful!
#
# HF index: [ 965  970  977  980  994 1000] 924
# Ground state energy untapered:           -37.21873355063707
# Ground state energy tapered with Qiskit: -37.21873355063634
# Ground state energy tapered with Andrew (andrew hf): -37.146189859805645
# Ground state energy tapered with Andrew (qiskit hf): -37.1461898598056
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# NH_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, -1, 1, 1), tapering successful!
#
# HF index: [4052 4072] 3900
# Ground state energy untapered:           -54.288892638743626
# Ground state energy tapered with Qiskit: -54.28889263874186
# Ground state energy tapered with Andrew (andrew hf): -54.19972893029703
# Ground state energy tapered with Andrew (qiskit hf): -54.19972893029718
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# Ne_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1, 1, -1, 1), tapering successful!
#
# Tapering went wrong
# F+_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, -1, 1, 1, 1), tapering successful!
#
# HF index: [ 991 1007 1015 1019 1021 1022] 990
# Ground state energy untapered:           -97.98650495873589
# Ground state energy tapered with Qiskit: -97.98650495873594
# Ground state energy tapered with Andrew (andrew hf): -97.61331469030684
# Ground state energy tapered with Andrew (qiskit hf): -97.61331469030658
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# Li+_STO-3G_SINGLET
# Attempting to taper 10 --> 5 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, 1, -1, 1), tapering successful!
#
# HF index: [832 896] 528
# Ground state energy untapered:           -7.315836552850669
# Ground state energy tapered with Qiskit: -7.315836552850669
# Ground state energy tapered with Andrew (andrew hf): -7.135654284252036
# Ground state energy tapered with Andrew (qiskit hf): -7.135654284252051
# Qiskit num qubits:  5
# Andrew num qubits:  5
#
# BH_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, -1), tapering successful!
#
# HF index: [4032] 3640
# Ground state energy untapered:           -24.809507022477156
# Ground state energy tapered with Qiskit: -24.809507022477252
# Ground state energy tapered with Andrew (andrew hf): -24.339173386617986
# Ground state energy tapered with Andrew (qiskit hf): -24.339173386617993
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# NeH+_STO-3G_SINGLET
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, 1), tapering successful!
#
# HF index: [4093 4094] 4030
# Ground state energy untapered:           -127.07110649521998
# Ground state energy tapered with Qiskit: -127.07110649522006
# Ground state energy tapered with Andrew (andrew hf): -126.76307338637449
# Ground state energy tapered with Andrew (qiskit hf): -126.76307338637396
# Qiskit num qubits:  8
# Andrew num qubits:  8
#
# NH2+_STO-3G_SINGLET
# Attempting to taper 14 --> 10 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (-1, 1, 1, 1), tapering successful!
#
# HF index: [16336 16352] 15480
# Ground state energy untapered:           -54.888946200775074
# Ground state energy tapered with Qiskit: -54.888946200775045
# Ground state energy tapered with Andrew (andrew hf): -54.62977845882001
# Ground state energy tapered with Andrew (qiskit hf): -54.62977845882028
# Qiskit num qubits:  10
# Andrew num qubits:  10
#
# BH2+_STO-3G_SINGLET
# Attempting to taper 14 --> 10 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, 1), tapering successful!
#
# HF index: [16192 16256] 14448
# Ground state energy untapered:           -25.44655209035624
# Ground state energy tapered with Qiskit: -25.446552090356445
# Ground state energy tapered with Andrew (andrew hf): -25.171958144261794
# Ground state energy tapered with Andrew (qiskit hf): -25.17195814426176
# Qiskit num qubits:  10
# Andrew num qubits:  10

# %% [markdown]
# # Qiskit tapering implementation

# %%
construct_mol=mol.construct_molecule(atoms=atoms, 
                                   coords=coords, 
                                   charge=charge, 
                                   multiplicity=mult, 
                                   basis=basis, 
                                   taper=False)
ham_untapered = construct_mol['hamiltonian']
untap_hf_config = construct_mol['hf_config']

# %%
construct_mol=mol.construct_molecule(atoms=atoms, 
                                   coords=coords, 
                                   charge=charge, 
                                   multiplicity=mult, 
                                   basis=basis, 
                                   taper=True, 
                                   sym_sector=sector)
ham_tapered_qiskit = construct_mol['hamiltonian']
# Out:
# Attempting to taper 12 --> 8 qubits
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Energies match in sector (1, 1, -1, -1), tapering successful!

# %%
ham_untap_mat = qonvert.dict_to_WeightedPauliOperator(ham_untapered).to_matrix()
ham_tap_1_mat   = qonvert.dict_to_WeightedPauliOperator(ham_tapered_qiskit).to_matrix()

# %% [markdown]
# # Original tapering implementation

# %%
ham_untapered_indexed = qonvert.dict_to_list_index(ham_untapered)

# %%
taper.hfDegenerateGroundState(ham_untapered_indexed)
# Out:
# [4092]
# <4096x1 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 1 stored elements in Compressed Sparse Column format>

# %%
hf_index = 4092#bit.bin_to_int(untap_hf_config)
ham_tapered_andrew = qonvert.index_list_to_dict(taper.taperOplist(oplist=ham_untapered_indexed, hfStateIndex=hf_index))
ham_tap_2_mat = qonvert.dict_to_WeightedPauliOperator(ham_tapered_andrew).to_matrix()

# %% [markdown]
# # Compare

# %%
print('Ground state energy untapered:          ',la.get_ground_state(ham_untap_mat)[0])
print('Ground state energy tapered with Qiskit:',la.get_ground_state(ham_tap_1_mat)[0])
print('Ground state energy tapered with Andrew:',la.get_ground_state(ham_tap_2_mat)[0])
# Out:
# Ground state energy untapered:           -98.60330177725983
# Ground state energy tapered with Qiskit: -98.60330177725861
# Ground state energy tapered with Andrew: -98.13175135661567

# %%
len(list(ham_tapered_andrew.keys())[0]), len(list(ham_tapered_qiskit.keys())[0])
# Out:
# (8, 8)
